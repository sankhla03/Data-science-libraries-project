# %%
from matplotlib import pylab

# %%
print(pylab.__version__)
# Out:
# 2.0.2

# %%
import numpy as np

# %%
x = np.linspace(0,10,25)
y = x+2
print(x)
print(y)
print(np.array([x,y]).reshape(25,2).reshape(2,25))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [ 2.          2.41666667  2.83333333  3.25        3.66666667  4.08333333
#   4.5         4.91666667  5.33333333  5.75        6.16666667  6.58333333
#   7.          7.41666667  7.83333333  8.25        8.66666667  9.08333333
#   9.5         9.91666667 10.33333333 10.75       11.16666667 11.58333333
#  12.        ]
# [[ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#    2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#    5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#    7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#   10.        ]
# ...

# %%
pylab.plot(x,y, 'r')

# %%
##Drawing a subgraph

# %%
pylab.subplot(1,2,1) #the content if the brackets represent(row,columns,indexes)
# Out:
# <Axes: >

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--') #the third parameter here determines color and line style.
pylab.subplot(1,2,2)
pylab.plot(x,y, 'g*-')

# %%
#operation Description

# %%
# fig.add_axes() = intiailize subplot a= fig.add_subplot(222)
# fig.b = plt.subplots(nrowa =3, nclos =2) = Adds subplot
# ax = plt.subplots(2,2) = creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure(figsize = (10,4), dpi= 300)  #New graphic object
fig.add_subplot()

plt.plot(x,y, 'r')

# %%
fig, axes = plt.subplots(nrows= 1, ncols =2)  #subplot is of 1 row , 2 columns
for ax in axes:
  ax.plot(x,y, 'r')

# %%
#we can draw a picture or grap, inside another graph

# %%
fig = plt.figure()
#control the left, right, width, height of the canvas(from 0 to 1
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #big axes
axes2 = fig.add_axes([0.2,0.7,0.3, 0.3])  # small camvas
axes1.plot(x,y, 'r')
axes2.plot(y,x, 'g')

# %%
fig = plt.figure(figsize = (10,4), dpi= 300)  #New graphic object
fig.add_subplot()

plt.plot(x,y, 'r')

# %%
fig = plt.figure(figsize =(7,2))
ax = fig.add_subplot(111)
ax.set_title("Title")  #here we give title to the axes
plt.plot(x,y, 'r')

# %%
# ax.legend(["label1", "label2"])
fig, axes = plt.subplots(dpi =200)
axes.set_xlabel("x- label")
axes.set_ylabel("y- label")
axes.set_title("title")

# axes.plot(x,y, 'r')
axes.plot(y, x**2 , 'b')
axes.plot(x, x**3, 'g')
axes.legend(["y = x**2","y =x**3"], loc =2)

# %%
#In matplotlib, you can set other peroperties such as line color, transparency, and, more.

# %%
fig , axes = plt.subplots(dpi=150)
axes.plot(x,x**2, color ='red', alpha = .3)
axes.plot(x, x+2 , color ='blue', alpha = .5)
axes.plot(x, x+3 ,alpha =.8)

# %%
fig, ax =plt.subplots(dpi=100)

#line width
ax.plot(x,x+1, color = 'blue', linewidth= 0.25)
ax.plot(x, x+2, color = 'blue', linewidth = 1)
ax.plot(x,x+3, color = 'blue', linewidth=1.5)
ax.plot(x,x+4, color = 'blue', linewidth =2)

# %%
fig, ax =plt.subplots(dpi=100)

#line style
ax.plot(x,x+1, color = 'blue', lw= 0.25, linestyle = "-")
ax.plot(x, x+2, color = 'blue', lw = 1, linestyle = '-.')
ax.plot(x,x+3, color = 'blue', lw=1.5, linestyle = ':')
line, =ax.plot(x,x+4, color = 'black', lw=1.50)

# %%
fig, ax =plt.subplots(dpi=100)

#line width
ax.plot(x,x+1, color = 'blue', marker ='o')
ax.plot(x, x+2, color = 'blue', marker = '+')
ax.plot(x,x+3, color = 'blue', marker = 's')
ax.plot(x,x+4, color = 'blue', marker ='1')
ax.plot(x,x+5, color = 'blue', marker ='o', markersize =20)
ax.plot(x,x+6, color = 'blue', marker ='o',markersize=5, markerfacecolor ='red')

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(x,x**2,x,x**3, lw=2)
ax[0].grid(True)
ax[1].plot(x,x**2,x,x**3, lw=2)
ax[1].set_ylim([0,60])
ax[1].set_xlim([2,5])
ax[1].grid(True)

# %%
#other 2D Graph

# %%
n = np.array([1,2,3,4,5])
fig, ax = plt.subplots(1,4, figsize = (16,5))
ax[0].set_title('Scatter')
ax[0].scatter(x,x+0.25*np.random.randn(len(x)))
ax[1].set_title("Step")
ax[1].step(n,n**2, lw =2)
ax[2].set_title("Bar")
ax[2].bar(n,n**2,align ="center",width=0.9, alpha =.5 )
ax[3].set_title("Fill_between")
ax[3].fill_between(x,x**2,x**3, color= 'green', alpha=0.5)

# %%
# Draw a radar Chart

# %%
fig = plt.figure(figsize =(6,6))
ax = fig.add_axes([0.0,0.0,.4,.4], polar =True)
t = np.linspace(0,2*np.pi,100)
ax.plot(t,t, color = 'blue', lw=1)

# %%
#Draw a Histogram
n = np.random.randn(100000)
fig, ax = plt.subplots(1,2,figsize=(12,4))
ax[0].set_title("Default Histogram")
ax[0].hist(n)

ax[1].set_title("Cumulative Detailed Histogram")
ax[1].hist(n, cumulative = True, bins=5)
# Out:
# (array([   121.,  11349.,  72527.,  99211., 100000.]),
#  array([-4.81735071, -3.01126495, -1.20517919,  0.60090658,  2.40699234,
#          4.2130781 ]),
#  <BarContainer object of 5 artists>)

# %%
#Draw contour imge

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y= np.arange(-2.0,2.0,delta)
x,y = np.meshgrid(x,y)
z1 = np.exp(-x**2 - y**2)
z2 = np.exp(-(x-1)**2 - (y-1)**2)
z = (z1-z2)*2

# %%
fig , ax = plt.subplots()
cs = ax.contour(x,y,z)
ax.clabel(cs, inline =1, fontsize=10)
ax.set_title('contour map')
print(x)
print(y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
# 3D surface imag

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1,2,1, projection = '3d')
ax.plot_surface(x,y,z,rstride=4,cstride=4,  linewidth = 0)

# %%
# write a Python programing to create a pie chart of the popularity of programing languange

# %%
#Data to plot
language = 'python','Java','Php', 'JAVAScript','c', 'c++'
popularity  = [22.2, 17.6,8.8,8,7.7,6.7]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c','#d62728', '#9467bd','#8c564b']

# %%
explode =(0.1,0,0,0,0,0)
plt.pie(popularity,explode = explode, labels = language, colors = colors, autopct='%1.1f%%', shadow = True, startangle =140)
# Out:
# ([<matplotlib.patches.Wedge at 0x7aa5edffbfb0>,
# ...
#  [Text(-1.1518738600274299, -0.33643217828487987, 'python'),
#   Text(0.5025193836400076, -0.978506141557664, 'Java'),
#   Text(1.0971674215735683, 0.07889010734945326, 'Php'),
#   Text(0.7543405271097618, 0.8006062510121731, 'JAVAScript'),
#   Text(0.06701861536005276, 1.0979565133443225, 'c'),
#   Text(-0.5993298503773844, 0.9223902267731496, 'c++')],
#  [Text(-0.671926418349334, -0.19625210399951326, '31.3%'),
#   Text(0.27410148198545864, -0.5337306226678167, '24.8%'),
#   Text(0.5984549572219462, 0.043030967645156314, '12.4%'),
#   Text(0.41145846933259733, 0.43669431873391257, '11.3%'),
#   Text(0.03655560837821059, 0.5988853709150849, '10.8%'),
#   Text(-0.3269071911149369, 0.5031219418762634, '9.4%')])
